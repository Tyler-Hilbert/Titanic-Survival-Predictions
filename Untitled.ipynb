# %%
import pandas as pd
import matplotlib.pyplot as pt
# %matplotlib inline

df = pd.read_csv("train.csv")
print (df['Age'].hist(bins=15))
print(df.loc[df['Survived'] == 1]['Age'].hist(bins=15))
# Out:
# Axes(0.125,0.125;0.775x0.775)
# Axes(0.125,0.125;0.775x0.775)
